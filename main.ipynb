# %%
import funciones
import funciones.utilidades

# Inicializar el juego
primer_juego = True
while True:
    funciones.utilidades.inicializar_juego(primer_juego=primer_juego)
    primer_juego = False
# Out:
# Bienvenido al juego: Adivina el número
# Instrucciones:
# El juego consiste en adivinar un número ENTERO entre 1 y 1000
# Después de cada intento, se te dará una pista: si el número a adivinar es mayor o menor a tu intento
# Acontinuación, podrás elegir el modod de juego y la dificultad.
# ¡Buena suerte!
# Selecciona el modo de juego:
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadística
# 4. Salir
# Has seleccionado el análisis de estadísticas
# Selecciona el tipo de estadística que deseas ver:
# 1. Estadísticas generales por Jugador
# 2. Estadísticas por dificultad
# 3. Salir
#
#                Jugados  Ganados  Perdidos  Puntos  Promedio intentos  \
# Dificultad
# Difícil              7        7         0     972           3.428571
# Fácil                5        5         0    1293           4.200000
# Normal               2        2         0     183           4.000000
# Personalizado        2        2         0     198           7.500000
#
#                Porcentaje Ganados  Porcentaje Perdidos  Porcentaje intentos
# Dificultad
# Difícil                     100.0                  0.0            31.142857
# Fácil                       100.0                  0.0            38.200000
# Normal                      100.0                  0.0            46.500000
# Personalizado               100.0                  0.0            75.000000
# Selecciona el tipo de estadística que deseas ver:
# 1. Estadísticas generales por Jugador
# 2. Estadísticas por dificultad
# 3. Salir
#
#                Jugados  Ganados  Perdidos  Puntos  Promedio intentos  \
# Dificultad
# Difícil              7        7         0     972           3.428571
# Fácil                5        5         0    1293           4.200000
# Normal               2        2         0     183           4.000000
# Personalizado        2        2         0     198           7.500000
#
#                Porcentaje Ganados  Porcentaje Perdidos  Porcentaje intentos
# Dificultad
# Difícil                     100.0                  0.0            31.142857
# Fácil                       100.0                  0.0            38.200000
# Normal                      100.0                  0.0            46.500000
# Personalizado               100.0                  0.0            75.000000
# Selecciona el tipo de estadística que deseas ver:
# 1. Estadísticas generales por Jugador
# 2. Estadísticas por dificultad
# 3. Salir
# Por favor, introduce un número válido.
#
# Selecciona el tipo de estadística que deseas ver:
# 1. Estadísticas generales por Jugador
# 2. Estadísticas por dificultad
# 3. Salir
#
#                Jugados  Ganados  Perdidos  Puntos  Promedio intentos  \
# Dificultad
# Difícil              7        7         0     972           3.428571
# Fácil                5        5         0    1293           4.200000
# Normal               2        2         0     183           4.000000
# Personalizado        2        2         0     198           7.500000
#
#                Porcentaje Ganados  Porcentaje Perdidos  Porcentaje intentos
# Dificultad
# Difícil                     100.0                  0.0            31.142857
# Fácil                       100.0                  0.0            38.200000
# Normal                      100.0                  0.0            46.500000
# Personalizado               100.0                  0.0            75.000000
# Selecciona el tipo de estadística que deseas ver:
# 1. Estadísticas generales por Jugador
# 2. Estadísticas por dificultad
# 3. Salir
#
#                Jugados  Ganados  Perdidos  Puntos  Promedio intentos  \
# Dificultad
# Difícil              7        7         0     972           3.428571
# Fácil                5        5         0    1293           4.200000
# Normal               2        2         0     183           4.000000
# Personalizado        2        2         0     198           7.500000
#
#                Porcentaje Ganados  Porcentaje Perdidos  Porcentaje intentos
# Dificultad
# Difícil                     100.0                  0.0            31.142857
# Fácil                       100.0                  0.0            38.200000
# Normal                      100.0                  0.0            46.500000
# Personalizado               100.0                  0.0            75.000000
# Selecciona el tipo de estadística que deseas ver:
# 1. Estadísticas generales por Jugador
# 2. Estadísticas por dificultad
# 3. Salir
#
#
# ¡Bienvenido de nuevo!
# Quieres intentarlo otra vez?
# Selecciona el modo de juego:
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadística
# 4. Salir
# ¡Gracias por jugar!
# Adios.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       5 primer_juego = True
#       6 while True:
# ----> 7     funciones.utilidades.inicializar_juego(primer_juego=primer_juego)
#       8     primer_juego = False
#
# File d:\OneDrive\Documentos\Formacion y cursos\DataScience UCM\Modulos\Python basico\Tarea\funciones\utilidades.py:84, in inicializar_juego(primer_juego)
#      82 print("¡Gracias por jugar!")
#      83 print("Adios.")
# ---> 84 exit()
#
# NameError: name 'exit' is not defined
